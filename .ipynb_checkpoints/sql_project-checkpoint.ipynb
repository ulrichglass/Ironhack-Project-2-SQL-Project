# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this

schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035    
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests

def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    # we use ID
    #reviews['school'] = school
    reviews['school_id'] = school_id
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard

# %%
# remove body column as replaced by review_body -> to do with loop through kill column list
comments.drop('body', inplace=True, axis=1)
comments.drop('user', inplace=True, axis=1)
comments.drop('comments', inplace=True, axis=1)
comments
# Out:
#          id           name  anonymous hostProgramName  graduatingYear  \
# 0    269512      Anonymous       True            None          2019.0
# 1    269343         Felipe      False            None          2020.0
# 2    269201   Ozzie Zamora      False            None          2020.0
# 3    269141    Sacha Dollé      False            None          2020.0
# 4    269133  Calypso Redor      False            None          2020.0
# ..      ...            ...        ...             ...             ...
# 693  234894   Stephanie S.      False            None          2015.0
# 694  234877       Joe Fang      False            None          2015.0
# 695  234838          Zeina      False            None          2016.0
# 696  242681           Jean      False            None          2016.0
# 697  234178            Ben      False            None          2016.0
#
#      isAlumni                         jobTitle  \
# 0       False             Full stack developer
# 1       False                       Unemployed
# 2       False                      UI Designer
# 3       False                     Data Analyst
# 4       False                 Product Designer
# ..        ...                              ...
# 693      True          Website Manager-UX Lead
# 694      True                      UX Designer
# 695      True          Senior Graphic Designer
# 696      True  Lead Designer/Creative Director
# 697      True                             None
#
#                                                tagline   createdAt  \
# 0    Great qualified teachers but unorganized, not ...  10/20/2020
# 1    UX UI Iron Hack Sao Paulo, be careful before y...  10/13/2020
# 2                       UX/UI Design Part-Time | Miami   10/7/2020
# 3           Great bootcamp, great team, great learning   10/6/2020
# 4                               Une superbe expérience   10/6/2020
# ..                                                 ...         ...
# 693              Excellent and comprehensive UX course  12/15/2016
# 694        Springboard helped me start my career in UX  12/15/2016
# 695                                 Highly recommended  12/15/2016
# 696    A way to stay current for the highly motivated!  12/12/2016
# 697  Springboard is an excellent course for self dr...  12/10/2016
#
#       queryDate                  program overallScore overall curriculum  \
# 0    2020-10-20                                   2.7     3.0        4.0
# 1    2020-10-13    UX/UI Design Bootcamp          3.3     2.0        5.0
# 2    2020-10-07   UX/UI Design Part-Time          5.0     5.0        5.0
# 3    2020-10-06  Data Analytics Bootcamp          5.0     5.0        5.0
# 4    2020-10-06                                   5.0     5.0        5.0
# ..          ...                      ...          ...     ...        ...
# 693  2016-12-15                UX Design          5.0     5.0        5.0
# 694  2016-12-15                UX Design          5.0     5.0        5.0
# 695  2016-12-15                UX Design          3.7     4.0        4.0
# 696  2016-12-12                UX Design          5.0     5.0        5.0
# 697  2016-12-10                UX Design          4.7     5.0        5.0
#
#     jobSupport                                        review_body       school
# 0          1.0  I attended the Berlin bootcamp and the biggest...     ironhack
# 1          3.0  (Por favor copie e cole no google tradutor se ...     ironhack
# 2          5.0  A truly amazing experience, to be honest. I wa...     ironhack
# 3          5.0  I use to work in advertisement and decided to ...     ironhack
# 4          5.0  « On m’avait prévenu de ce que voulait dire « ...     ironhack
# ..         ...                                                ...          ...
# 693        5.0  The UX Design Workshop gave me a great underst...  springboard
# 694        5.0  Just some background information on myself, I ...  springboard
# 695        3.0  I enjoyed the program very much, gained a lot ...  springboard
# 696        5.0  This was my first online experience and it did...  springboard
# 697        4.0  I really enjoyed my time with the Springboard ...  springboard
#
# [2640 rows x 17 columns]

# %%
#df = df.astype(object).where(pd.notnull(df), None)
# replace Pandas NaN to NULL for SQL
comments = comments.astype(object).where(pd.notnull(comments), None)
comments
# Out:
#          id           name anonymous hostProgramName graduatingYear isAlumni  \
# 0    269512      Anonymous      True            None           2019    False
# 1    269343         Felipe     False            None           2020    False
# 2    269201   Ozzie Zamora     False            None           2020    False
# 3    269141    Sacha Dollé     False            None           2020    False
# 4    269133  Calypso Redor     False            None           2020    False
# ..      ...            ...       ...             ...            ...      ...
# 693  234894   Stephanie S.     False            None           2015     True
# 694  234877       Joe Fang     False            None           2015     True
# 695  234838          Zeina     False            None           2016     True
# 696  242681           Jean     False            None           2016     True
# 697  234178            Ben     False            None           2016     True
#
#                             jobTitle  \
# 0               Full stack developer
# 1                         Unemployed
# 2                        UI Designer
# 3                       Data Analyst
# 4                   Product Designer
# ..                               ...
# 693          Website Manager-UX Lead
# 694                      UX Designer
# 695          Senior Graphic Designer
# 696  Lead Designer/Creative Director
# 697                             None
#
#                                                tagline   createdAt  \
# 0    Great qualified teachers but unorganized, not ...  10/20/2020
# 1    UX UI Iron Hack Sao Paulo, be careful before y...  10/13/2020
# 2                       UX/UI Design Part-Time | Miami   10/7/2020
# 3           Great bootcamp, great team, great learning   10/6/2020
# 4                               Une superbe expérience   10/6/2020
# ..                                                 ...         ...
# 693              Excellent and comprehensive UX course  12/15/2016
# 694        Springboard helped me start my career in UX  12/15/2016
# 695                                 Highly recommended  12/15/2016
# 696    A way to stay current for the highly motivated!  12/12/2016
# 697  Springboard is an excellent course for self dr...  12/10/2016
#
#       queryDate                  program overallScore overall curriculum  \
# 0    2020-10-20                                   2.7     3.0        4.0
# 1    2020-10-13    UX/UI Design Bootcamp          3.3     2.0        5.0
# 2    2020-10-07   UX/UI Design Part-Time          5.0     5.0        5.0
# 3    2020-10-06  Data Analytics Bootcamp          5.0     5.0        5.0
# 4    2020-10-06                                   5.0     5.0        5.0
# ..          ...                      ...          ...     ...        ...
# 693  2016-12-15                UX Design          5.0     5.0        5.0
# 694  2016-12-15                UX Design          5.0     5.0        5.0
# 695  2016-12-15                UX Design          3.7     4.0        4.0
# 696  2016-12-12                UX Design          5.0     5.0        5.0
# 697  2016-12-10                UX Design          4.7     5.0        5.0
#
#     jobSupport                                        review_body       school
# 0          1.0  I attended the Berlin bootcamp and the biggest...     ironhack
# 1          3.0  (Por favor copie e cole no google tradutor se ...     ironhack
# 2          5.0  A truly amazing experience, to be honest. I wa...     ironhack
# 3          5.0  I use to work in advertisement and decided to ...     ironhack
# 4          5.0  « On m’avait prévenu de ce que voulait dire « ...     ironhack
# ..         ...                                                ...          ...
# 693        5.0  The UX Design Workshop gave me a great underst...  springboard
# 694        5.0  Just some background information on myself, I ...  springboard
# 695        3.0  I enjoyed the program very much, gained a lot ...  springboard
# 696        5.0  This was my first online experience and it did...  springboard
# 697        4.0  I really enjoyed my time with the Springboard ...  springboard
#
# [2640 rows x 17 columns]

# %%
# Test to SQL
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@database-1.cq4pvdaebaqt.us-east-2.rds.amazonaws.com/{db}"
                       .format(user="root",
                               pw="letmein123",
                               db="sql_project"))
# Insert whole DataFrame into MySQL
comments.to_sql('comments', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     187             assert q_values[0] == '(' and q_values[-1] == ')'
# --> 188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     221             if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 222                 rows += self.execute(sql + postfix)
#     223                 sql = bytearray(prefix)
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'index' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-194da9aacc64> in <module>
#       6                                db="sql_project"))
#       7 # Insert whole DataFrame into MySQL
# ----> 8 comments.to_sql('comments', con = engine, if_exists = 'append', chunksize = 1000)
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     146
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#     150             context._rowcount = rowcount
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     186             q_postfix = m.group(3) or ''
#     187             assert q_values[0] == '(' and q_values[-1] == ')'
# --> 188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
#     190                                          self._get_db().encoding)
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     220                     v = v.encode(encoding, 'surrogateescape')
#     221             if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 222                 rows += self.execute(sql + postfix)
#     223                 sql = bytearray(prefix)
#     224             else:
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column 'index' in 'field list'")
# [SQL: INSERT INTO comments (`index`, id, name, anonymous, `hostProgramName`, `graduatingYear`, `isAlumni`, `jobTitle`, tagline, `createdAt`, `queryDate`, program, `overallScore`, overall, curriculum, `jobSupport`, review_body, school) VALUES (%(index)s, %(id)s, %(name)s, %(anonymous)s, %(hostProgramName)s, %(graduatingYear)s, %(isAlumni)s, %(jobTitle)s, %(tagline)s, %(createdAt)s, %(queryDate)s, %(program)s, %(overallScore)s, %(overall)s, %(curriculum)s, %(jobSupport)s, %(review_body)s, %(school)s)]
# [parameters: ({'index': 0, 'id': 269512, 'name': 'Anonymous', 'anonymous': 1, 'hostProgramName': None, 'graduatingYear': 2019.0, 'isAlumni': 0, 'jobTitle': 'Full stack developer', 'tagline': 'Great qualified teachers but unorganized, not transparent and poor alumni support.', 'createdAt': '10/20/2020', 'queryDate': '2020-10-20', 'program': '', 'overallScore': '2.7', 'overall': '3.0', 'curriculum': '4.0', 'jobSupport': '1.0', 'review_body': 'I attended the Berlin bootcamp and the biggest pro is that the teachers and assistants are highly qualified and have real experience in the industry. ... (648 characters truncated) ... terial. The worse part of this entire experience is that they never addressed our concerns. I would not recommend studying at this bootcamp!Read Less', 'school': 'ironhack'}, {'index': 1, 'id': 269343, 'name': 'Felipe', 'anonymous': 0, 'hostProgramName': None, 'graduatingYear': 2020.0, 'isAlumni': 0, 'jobTitle': 'Unemployed', 'tagline': 'UX UI Iron Hack Sao Paulo, be careful before you sign up. Excellent curriculum, but poor customer service.', 'createdAt': '10/13/2020', 'queryDate': '2020-10-13', 'program': 'UX/UI Design Bootcamp', 'overallScore': '3.3', 'overall': '2.0', 'curriculum': '5.0', 'jobSupport': '3.0', 'review_body': "(Por favor copie e cole no google tradutor se você é um futuro estudante e esta pesquisando sobre qual escola ir) Covid 19, lost my Grandpa, lost two ... (1525 characters truncated) ... the link for the recording class, that's it! I Paid for that, that's why I think it’s the minimum thing that I could get back from you guys.Read Less", 'school': 'ironhack'}, {'index': 2, 'id': 269201, 'name': 'Ozzie Zamora', 'anonymous': 0, 'hostProgramName': None, 'graduatingYear': 2020.0, 'isAlumni': 0, 'jobTitle': 'UI Designer', 'tagline': 'UX/UI Design Part-Time | Miami', 'createdAt': '10/7/2020', 'queryDate': '2020-10-07', 'program': 'UX/UI Design Part-Time', 'overallScore': '5.0', 'overall': '5.0', 'curriculum': '5.0', 'jobSupport': '5.0', 'review_body': 'A truly amazing experience, to be honest. I was part of the Part-Time UX Design course for 6 months, and I cannot really describe how much I enjoyed  ... (1579 characters truncated) ...  people fail after the course, in my opinion)- Participate in meetups and reach out to the community for help if necessary, do not be afraidRead Less', 'school': 'ironhack'}, {'index': 3, 'id': 269141, 'name': 'Sacha Dollé', 'anonymous': 0, 'hostProgramName': None, 'graduatingYear': 2020.0, 'isAlumni': 0, 'jobTitle': 'Data Analyst', 'tagline': 'Great bootcamp, great team, great learning', 'createdAt': '10/6/2020', 'queryDate': '2020-10-06', 'program': 'Data Analytics Bootcamp', 'overallScore': '5.0', 'overall': '5.0', 'curriculum': '5.0', 'jobSupport': '5.0', 'review_body': "I use to work in advertisement and decided to move into data through a bootcamp.I was in Paris' June Data Analysis bootcamp, which were 100% remote d ... (260 characters truncated) ...  to learn efficiently in such a short time.I'm really glad I had the chance to attend this bootcamp, because today I'm a proud Data Analyst.Read Less", 'school': 'ironhack'}, {'index': 4, 'id': 269133, 'name': 'Calypso Redor', 'anonymous': 0, 'hostProgramName': None, 'graduatingYear': 2020.0, 'isAlumni': 0, 'jobTitle': 'Product Designer', 'tagline': 'Une superbe expérience', 'createdAt': '10/6/2020', 'queryDate': '2020-10-06', 'program': '', 'overallScore': '5.0', 'overall': '5.0', 'curriculum': '5.0', 'jobSupport': '5.0', 'review_body': '«\xa0On m’avait prévenu de ce que voulait dire «\xa0bootcamp\xa0» mais je ne m’attendais pas à un tel rythme\xa0», c’est ce que j’ai beaucoup dit en  ... (456 characters truncated) ... s. Nous avons réalisé la formation à distance et ce fut tellement concluant que je compte travailler en entreprise full remote très bientôt.Read Less', 'school': 'ironhack'}, {'index': 5, 'id': 269115, 'name': 'Linda Mai Phung', 'anonymous': 0, 'hostProgramName': None, 'graduatingYear': 2020.0 ...
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Opening and initializing the SQL connection

import mysql.connector
cnx = mysql.connector.connect(user = 'root',password = 'letmein123', host ='database-1.cq4pvdaebaqt.us-east-2.rds.amazonaws.com', database = 'sql_project')
#cnx = mysql.connector.connect(user = 'root',password = 'letmein123', host ='localhost', database = 'sql_project')

if cnx.is_connected():
    print("Connection open")
    # do stuff you need to the database
else:
    print("Connection is not successfully open")

cursor = cnx.cursor()
# Out:
# Connection open

# %%
# Inserting Comments Data
# creating column list for insertion
cols = "`,`".join([str(i) for i in comments.columns.tolist()])
# Insert DataFrame recrds one by one.
for i,row in comments.iterrows():
    sql = "INSERT INTO `comments` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cursor.execute(sql, tuple(row))

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    # No need, we use ID
    #locations_df['school'] = school
    #courses_df['school'] = school
    #badges_df['school'] = school
    #school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-17-7111c633f1e2>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# app-academy
# springboard

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ]

# %%
locations = pd.concat(locations_list)

# replace Pandas NaN to NULL for SQL
locations = locations.astype(object).where(pd.notnull(comments), None)
locations
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-33cad68610e5> in <module>
#       2
#       3 # replace Pandas NaN to NULL for SQL
# ----> 4 locations = locations.astype(object).where(pd.notnull(comments), None)
#       5 locations
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9002         """
#    9003         other = com.apply_if_callable(other, self)
# -> 9004         return self._where(
#    9005             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    9006         )
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8859
#    8860         else:
# -> 8861             new_data = self._mgr.where(
#    8862                 other=other,
#    8863                 cond=cond,
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/internals/managers.py in where(self, other, cond, align, errors, try_cast, axis)
#     521             other = extract_array(other, extract_numpy=True)
#     522
# --> 523         return self.apply(
#     524             "where",
#     525             align_keys=align_keys,
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/internals/blocks.py in where(self, other, cond, errors, try_cast, axis)
#    1351             # or if we are a single block (ndim == 1)
#    1352             try:
# -> 1353                 result = where_func(cond, values, other)
#    1354             except TypeError:
#    1355
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/internals/blocks.py in where_func(cond, values, other)
#    1342             # By the time we get here, we should have all Series/Index
#    1343             #  args extracted to  ndarray
# -> 1344             fastres = expressions.where(cond, values, other)
#    1345             return fastres
#    1346
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/computation/expressions.py in where(cond, a, b, use_numexpr)
#     247         Whether to try to use numexpr.
#     248     """
# --> 249     return _where(cond, a, b) if use_numexpr else _where_standard(cond, a, b)
#     250
#     251
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _where_standard(cond, a, b)
#     159 def _where_standard(cond, a, b):
#     160     # Caller is responsible for extracting ndarray if necessary
# --> 161     return np.where(cond, a, b)
#     162
#     163
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: operands could not be broadcast together with shapes (42,14) (14,14) ()

# %%
# Test to SQL
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@database-1.cq4pvdaebaqt.us-east-2.rds.amazonaws.com/{db}"
                       .format(user="root",
                               pw="letmein123",
                               db="sql_project"))
# Insert whole DataFrame into MySQL
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 1000)

# %%
# Inserting Location Data - OBSOLETE

# 2 Problems:
#    1) SQL does not accept '.' in table column name -> replace with '_'
#    2) Pandas NaN values do not automatically in NULL SQL values -> find solution

# creating column list for insertion
#cols = "`,`".join([str(i).replace('.','_') for i in locations.columns.tolist()])
# Insert DataFrame recrds one by one.
#for i,row in locations.iterrows():
#    sql = "INSERT INTO `locations` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
#    cursor.execute(sql, tuple(row))

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                               courses       school  school_id
# 0             Data Analytics Bootcamp     ironhack      10828
# 1            Data Analytics Part-Time     ironhack      10828
# 2               UX/UI Design Bootcamp     ironhack      10828
# 3              UX/UI Design Part-Time     ironhack      10828
# 4            Web Development Bootcamp     ironhack      10828
# 5           Web Development Part-Time     ironhack      10828
# 6             Cyber Security Bootcamp     ironhack      10828
# 0                       Bootcamp Prep  app-academy      10525
# 1  Software Engineer Track: In-Person  app-academy      10525
# 2     Software Engineer Track: Online  app-academy      10525

# %%
# Inserting Courses Data
# creating column list for insertion
cols = "`,`".join([str(i) for i in courses.columns.tolist()])
# Insert DataFrame recrds one by one.
for i,row in courses.iterrows():
    sql = "INSERT INTO `courses` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cursor.execute(sql, tuple(row))

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525

# %%
# Inserting Badges Data
# creating column list for insertion
cols = "`,`".join([str(i) for i in badges.columns.tolist()])
# Insert DataFrame recrds one by one.
for i,row in badges.iterrows():
    sql = "INSERT INTO `badges` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cursor.execute(sql, tuple(row))

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Springboard is an...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035

# %%
# Inserting School Data
# creating column list for insertion
cols = "`,`".join([str(i) for i in schools.columns.tolist()])
# Insert DataFrame recrds one by one.
for i,row in schools.iterrows():
    sql = "INSERT INTO `schools` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cursor.execute(sql, tuple(row))
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     503                 query = query.encode('utf-8')
# --> 504             self._cmysql.query(query,
#     505                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Duplicate entry '10828' for key 'schools.PRIMARY'
#
# During handling of the above exception, another exception occurred:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-32-0d00a5b802e3> in <module>
#       5 for i,row in schools.iterrows():
#       6     sql = "INSERT INTO `schools` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
# ----> 7     cursor.execute(sql, tuple(row))
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     262
#     263         try:
# --> 264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
#     266                                          raw_as_string=self._raw_as_string)
#
# ~/anaconda3/envs/sql_project/lib/python3.8/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     506                                raw_as_string=raw_as_string)
#     507         except MySQLInterfaceError as exc:
# --> 508             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     509                                              sqlstate=exc.sqlstate)
#     510         except AttributeError:
#
# IntegrityError: 1062 (23000): Duplicate entry '10828' for key 'schools.PRIMARY'

# %%
# commiting and closing curser and connection with SQL

# saving any changes you did on the database
cnx.commit()
# clear the cursor
cursor.close()

# closes the door between python and SQL
cnx.close()
